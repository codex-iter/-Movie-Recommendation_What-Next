# %%
#Before running the code the Original csv file was converted to .xlsx(Excel) file:
#dfc = pd.read_csv('Original.csv') 
#dfe = pd.ExcelWriter('Names.xlsx') 
#dfc.to_excel(dfe, index = False) 
#dfe.save() 
import pandas as pd
df=pd.read_excel('Names.xlsx')

# %%
df
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
def compareTo(self, that):
    return ((self > that) - (self < that))

# %%
df.drop(df[df['year']=='TV Movie 2019'].index, inplace = True)

# %%
df.drop(df[df['year'].astype(int) < 2000].index, inplace = True)
df.drop(df[df['duration'].astype(int)<=90].index, inplace=True)
# Out:
# array(['English, French', 'Japanese', 'English, German', ...,
#        'English, Swiss German, German',
#        'English, Polish, Russian, German', 'German, Dutch'], dtype=object)

# %%
df
# Out:
#       Unnamed: 0 imdb_title_id                           title  \
# 0           4334     tt0035423                  Kate & Leopold
# 1          14127     tt0064730      Nihon boryoku-dan: Kumicho
# 2          15675     tt0069049        L'altra faccia del vento
# 3          21806     tt0088751               The Naked Monster
# 4          24217     tt0096056               Delitto e castigo
# ...          ...           ...                             ...
# 47131      85849     tt9906644                       Manoharam
# 47132      85850     tt9908390                         Le lion
# 47133      85851     tt9911196  De Beentjes van Sint-Hildegard
# 47134      85852     tt9911774       Padmavyuhathile Abhimanyu
# 47135      85853     tt9914286               Sokagin Çocuklari
#
#                        original_title  year date_published  \
# 0                      Kate & Leopold  2001     2002-03-01
# 1          Nihon boryoku-dan: Kumicho  2000           1969
# ...

# %%
df.to_csv('filtered1.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7d88de4865d1> in <module>
# ----> 1 df=pd.read_csv("filtered1.csv", dtype='unicode')
#
# NameError: name 'pd' is not defined

# %%
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'imdb_title_id', 'title',
#        'original_title', 'year', 'date_published', 'genre', 'duration',
#        'country', 'language', 'director', 'writer', 'production_company',
#        'actors', 'description', 'avg_vote', 'votes', 'budget',
#        'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics', 'combined_features'],
#       dtype='object')

# %%
# Out:
# 0    Combined features:Comedy, Fantasy, Romance USA...
# 1    Combined features:Action, Crime Japan Kinji Fu...
# 2    Combined features:Drama France, Iran, USA Orso...
# 3    Combined features:Comedy, Horror, Sci-Fi USA W...
# 4    Combined features:Drama Poland, Russia, USA Me...
# Name: combined_features, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-63-448058d44435> in <module>
# ----> 1 cosineSimilarity=cosine_similarity(matrix)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in cosine_similarity(X, Y, dense_output)
#    1184         Y_normalized = normalize(Y, copy=True)
#    1185
# -> 1186     K = safe_sparse_dot(X_normalized, Y_normalized.T,
#    1187                         dense_output=dense_output)
#    1188
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     151             ret = np.dot(a, b)
# ...
